# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.loc[df['fulfilled-by'].isna()]
# Out:
#          index             Order ID      Date     Status Fulfilment  \
# 2            2  404-0687676-7273146  04-30-22    Shipped     Amazon
# 4            4  407-1069790-7240320  04-30-22    Shipped     Amazon
# 5            5  404-1490984-4578765  04-30-22    Shipped     Amazon
# 6            6  408-5748499-6859555  04-30-22    Shipped     Amazon
# 8            8  407-5443024-5233168  04-30-22  Cancelled     Amazon
# ...        ...                  ...       ...        ...        ...
# 128971  128970  406-6001380-7673107  05-31-22    Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22    Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22    Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22    Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22    Shipped     Amazon
#
#        Sales Channel ship-service-level  Category Size Courier Status  ...  \
# ...

# %%
df.drop(columns=['New','PendingS'],inplace=True)

# %%
df=df.dropna(
    
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  object
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
df['ship-postal-code']=df['ship-postal-code'].astype('int')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10144\1417998457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ship-postal-code']=df['ship-postal-code'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  object
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10144\3023999556.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\hp\AppData\Local\Temp\ipykernel_10144\3023999556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']=pd.to_datetime(df['Date'])

# %% [markdown]
# ### Rename columns

# %%
df.rename(columns={'Qty':'Quantity','ship-city':'city'},inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10144\3127120189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Qty':'Quantity','ship-city':'city'},inplace=True)

# %%
df.describe(include='object')
# Out:
#                    Order ID                        Status Fulfilment  \
# count                 37514                         37514      37514
# unique                34664                            11          1
# top     171-5057375-2831560  Shipped - Delivered to Buyer   Merchant
# freq                     12                         28741      37514
#
#        Sales Channel ship-service-level Category   Size Courier Status  \
# count          37514              37514    37514  37514          37514
# unique             1                  1        8     11              3
# top        Amazon.in           Standard  T-shirt      M        Shipped
# freq           37514              37514    14062   6806          31859
#
#        currency       city   ship-state ship-country fulfilled-by
# count     37514      37514        37514        37514        37514
# unique        1       4698           58            1            1
# ...

# %%
df[['Quantity','Amount']].describe()
# Out:
#            Quantity        Amount
# count  37514.000000  37514.000000
# mean       0.867383    646.553960
# std        0.354160    279.952414
# min        0.000000      0.000000
# 25%        1.000000    458.000000
# 50%        1.000000    629.000000
# 75%        1.000000    771.000000
# max        5.000000   5495.000000

# %% [markdown]
# EDA

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
sns.countplot(data=df,x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
ax=sns.countplot(data=df,x='Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.countplot(data=df,x='Size',order=['Free','S','XS','M','L','XL','XXL','3XL','4XL','5XL','6XL'])
# Out:
# <Axes: xlabel='Size', ylabel='count'>

# %% [markdown]
# Groupby

# %%
size_qty=df.groupby(['Size'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)

# %%
sns.barplot(x='Size',y='Quantity',data=size_qty)
# Out:
# <Axes: xlabel='Size', ylabel='Quantity'>

# %% [markdown]
# #### The highest amount of size sold were of M(Medium size)

# %% [markdown]
# Courier status

# %%
# plt.figure(figsize=(10,20))
ax=sns.countplot(df,x='Courier Status',hue='Status')
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# #### Most of the orders were delivered to the buyer

# %%
plt.figure(figsize=(10,5))
plt.hist(data=df,x='Category',bins=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### Most of the purchases were Tshirts

# %%
B2B_check=df['B2B'].value_counts()
plt.pie(B2B_check,labels=B2B_check.index,autopct='%1.1f')
plt.show()

# %% [markdown]
# ##### the above graph shows 99.2% of buyers are retailers and 0.8% are B2B buyers

# %%
sns.scatterplot(data=df,x='Category',y='Size')
# Out:
# <Axes: xlabel='Category', ylabel='Size'>

# %%
plt.figure(figsize=(15,8))
# plt.xlabel('ate')
# plt.ylabel('coustnt')
# plt.title('Dis/tribution')
plt.xticks(rotation=90)
ax=sns.countplot(data=df,x='ship-state')
for i in ax.containers:
    ax.bar_label(i)


plt.show()

# %%
top=df['ship-state'].value_counts().head(10)

# %%
sns.countplot(data=df[df['ship-state'].isin(top.index)],x='ship-state')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### most of the buyers are from maharastra

# %% [markdown]
# ### conclusion
#
# from all the above analysis we can declare that the most buyers are from maharastra who bought tshirts of size medium and were sold by retailers fulfilled by amazon.
